# %%
import tensorflow as tf
from tensorflow import keras

# %%
import keras_tuner as kt

# %%
(img_train, label_train), (img_test, label_test) = keras.datasets.fashion_mnist.load_data()

# %%
img_train = img_train.astype('float32') / 255.0
img_test = img_test.astype('float32') / 255.0

# %%
def model_builder(hp):
    model = keras.Sequential()
    model.add(keras.layers.Flatten(input_shape=(28, 28)))

    hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
    model.add(keras.layers.Dense(units=hp_units, activation='relu'))
    model.add(keras.layers.Dense(10))

    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                  loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])

    return model

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_accuracy',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt')
# Out:
# INFO:tensorflow:Reloading Oracle from existing project my_dir/intro_to_kt/oracle.json
# INFO:tensorflow:Reloading Tuner from my_dir/intro_to_kt/tuner0.json

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(img_train, label_train, epochs=50, validation_split=0.2, callbacks=[stop_early])

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 352 and the optimal learning rate for the optimizer
# is 0.001.

# %%
model = tuner.hypermodel.build(best_hps)
history = model.fit(img_train, label_train, epochs=50, validation_split=0.2)

val_acc_per_epoch = history.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print("Best epoch: %d" % (best_epoch,))
# Out:
# Epoch 1/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.4971 - accuracy: 0.8231 - val_loss: 0.3939 - val_accuracy: 0.8610
# Epoch 2/50
# 1500/1500 [==============================] - 1s 789us/step - loss: 0.3713 - accuracy: 0.8653 - val_loss: 0.3550 - val_accuracy: 0.8717
# Epoch 3/50
# 1500/1500 [==============================] - 1s 785us/step - loss: 0.3288 - accuracy: 0.8792 - val_loss: 0.3499 - val_accuracy: 0.8734
# Epoch 4/50
# 1500/1500 [==============================] - 1s 845us/step - loss: 0.3072 - accuracy: 0.8874 - val_loss: 0.3314 - val_accuracy: 0.8798
# Epoch 5/50
# 1500/1500 [==============================] - 1s 811us/step - loss: 0.2848 - accuracy: 0.8938 - val_loss: 0.3275 - val_accuracy: 0.8802
# Epoch 6/50
# 1500/1500 [==============================] - 1s 790us/step - loss: 0.2714 - accuracy: 0.8997 - val_loss: 0.3154 - val_accuracy: 0.8863
# Epoch 7/50
# 1500/1500 [==============================] - 1s 913us/step - loss: 0.2551 - accuracy: 0.9055 - val_loss: 0.3031 - val_accuracy: 0.8888
# Epoch 8/50
# 1500/1500 [==============================] - 1s 766us/step - loss: 0.2441 - accuracy: 0.9097 - val_loss: 0.3237 - val_accuracy: 0.8839
# Epoch 9/50
# 1500/1500 [==============================] - 1s 799us/step - loss: 0.2324 - accuracy: 0.9147 - val_loss: 0.3186 - val_accuracy: 0.8880
# Epoch 10/50
# 1500/1500 [==============================] - 1s 789us/step - loss: 0.2240 - accuracy: 0.9173 - val_loss: 0.3284 - val_accuracy: 0.8869
# Epoch 11/50
# 1500/1500 [==============================] - 1s 797us/step - loss: 0.2165 - accuracy: 0.9185 - val_loss: 0.3121 - val_accuracy: 0.8953
# Epoch 12/50
# 1500/1500 [==============================] - 1s 799us/step - loss: 0.2072 - accuracy: 0.9221 - val_loss: 0.3223 - val_accuracy: 0.8889
# Epoch 13/50
# 1500/1500 [==============================] - 1s 838us/step - loss: 0.1995 - accuracy: 0.9256 - val_loss: 0.3209 - val_accuracy: 0.8955
# Epoch 14/50
# 1500/1500 [==============================] - 1s 939us/step - loss: 0.1936 - accuracy: 0.9269 - val_loss: 0.3367 - val_accuracy: 0.8851
# Epoch 15/50
# 1500/1500 [==============================] - 1s 866us/step - loss: 0.1845 - accuracy: 0.9296 - val_loss: 0.3169 - val_accuracy: 0.8942
# Epoch 16/50
# 1500/1500 [==============================] - 1s 874us/step - loss: 0.1805 - accuracy: 0.9309 - val_loss: 0.3197 - val_accuracy: 0.8954
# Epoch 17/50
# 1500/1500 [==============================] - 1s 816us/step - loss: 0.1732 - accuracy: 0.9358 - val_loss: 0.3446 - val_accuracy: 0.8890
# Epoch 18/50
# 1500/1500 [==============================] - 1s 800us/step - loss: 0.1666 - accuracy: 0.9374 - val_loss: 0.3476 - val_accuracy: 0.8906
# Epoch 19/50
# 1500/1500 [==============================] - 1s 795us/step - loss: 0.1647 - accuracy: 0.9376 - val_loss: 0.3556 - val_accuracy: 0.8910
# Epoch 20/50
# 1500/1500 [==============================] - 1s 861us/step - loss: 0.1579 - accuracy: 0.9405 - val_loss: 0.3458 - val_accuracy: 0.8909
# Epoch 21/50
# 1500/1500 [==============================] - 1s 960us/step - loss: 0.1527 - accuracy: 0.9431 - val_loss: 0.3649 - val_accuracy: 0.8936
# Epoch 22/50
# 1500/1500 [==============================] - 1s 858us/step - loss: 0.1469 - accuracy: 0.9437 - val_loss: 0.3860 - val_accuracy: 0.8838
# Epoch 23/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1440 - accuracy: 0.9464 - val_loss: 0.3629 - val_accuracy: 0.8918
# Epoch 24/50
# 1500/1500 [==============================] - 1s 778us/step - loss: 0.1405 - accuracy: 0.9468 - val_loss: 0.3677 - val_accuracy: 0.8960
# Epoch 25/50
# 1500/1500 [==============================] - 1s 783us/step - loss: 0.1340 - accuracy: 0.9494 - val_loss: 0.3851 - val_accuracy: 0.8950
# Epoch 26/50
# 1500/1500 [==============================] - 1s 905us/step - loss: 0.1317 - accuracy: 0.9500 - val_loss: 0.4221 - val_accuracy: 0.8899
# Epoch 27/50
#  - ETA: 0s - loss: 0.1278 - accuracy: 0.9509
# Epoch 28/50
# 1500/1500 [==============================] - 1s 821us/step - loss: 0.1266 - accuracy: 0.9521 - val_loss: 0.3989 - val_accuracy: 0.8923
# Epoch 29/50
# 1500/1500 [==============================] - 1s 899us/step - loss: 0.1194 - accuracy: 0.9545 - val_loss: 0.3958 - val_accuracy: 0.8963
# Epoch 30/50
# 1500/1500 [==============================] - 1s 822us/step - loss: 0.1197 - accuracy: 0.9542 - val_loss: 0.4093 - val_accuracy: 0.8914
# Epoch 31/50
# 1500/1500 [==============================] - 1s 804us/step - loss: 0.1132 - accuracy: 0.9574 - val_loss: 0.4337 - val_accuracy: 0.8905
# Epoch 32/50
# 1500/1500 [==============================] - 1s 981us/step - loss: 0.1136 - accuracy: 0.9581 - val_loss: 0.4144 - val_accuracy: 0.8907
# Epoch 33/50
# 1500/1500 [==============================] - 1s 901us/step - loss: 0.1094 - accuracy: 0.9585 - val_loss: 0.3969 - val_accuracy: 0.8959
# Epoch 34/50
# 1500/1500 [==============================] - 1s 814us/step - loss: 0.1070 - accuracy: 0.9595 - val_loss: 0.4169 - val_accuracy: 0.8928
# Epoch 35/50
# 1500/1500 [==============================] - 1s 973us/step - loss: 0.1059 - accuracy: 0.9603 - val_loss: 0.4352 - val_accuracy: 0.8953
# Epoch 36/50
# 1500/1500 [==============================] - 1s 809us/step - loss: 0.1025 - accuracy: 0.9611 - val_loss: 0.4582 - val_accuracy: 0.8893
# Epoch 37/50
# 1500/1500 [==============================] - 1s 982us/step - loss: 0.1013 - accuracy: 0.9614 - val_loss: 0.4375 - val_accuracy: 0.8914
# Epoch 38/50
# 1500/1500 [==============================] - 1s 784us/step - loss: 0.0995 - accuracy: 0.9631 - val_loss: 0.4500 - val_accuracy: 0.8905
# Epoch 39/50
# 1500/1500 [==============================] - 1s 784us/step - loss: 0.0947 - accuracy: 0.9644 - val_loss: 0.4575 - val_accuracy: 0.8958
# Epoch 40/50
# 1500/1500 [==============================] - 1s 844us/step - loss: 0.0938 - accuracy: 0.9646 - val_loss: 0.4539 - val_accuracy: 0.8955
# Epoch 41/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0903 - accuracy: 0.9666 - val_loss: 0.4405 - val_accuracy: 0.8976
# Epoch 42/50
# 1500/1500 [==============================] - 1s 927us/step - loss: 0.0913 - accuracy: 0.9659 - val_loss: 0.4578 - val_accuracy: 0.8947
# Epoch 43/50
# 1500/1500 [==============================] - 1s 869us/step - loss: 0.0884 - accuracy: 0.9675 - val_loss: 0.4687 - val_accuracy: 0.8883
# Epoch 44/50
# 1500/1500 [==============================] - 1s 886us/step - loss: 0.0827 - accuracy: 0.9685 - val_loss: 0.5053 - val_accuracy: 0.8935
# Epoch 45/50
# 1500/1500 [==============================] - 1s 819us/step - loss: 0.0827 - accuracy: 0.9685 - val_loss: 0.5508 - val_accuracy: 0.8884
# Epoch 46/50
# 1500/1500 [==============================] - 1s 847us/step - loss: 0.0851 - accuracy: 0.9668 - val_loss: 0.5011 - val_accuracy: 0.8907
# Epoch 47/50
#  - ETA: 0s - loss: 0.0788 - accuracy: 0.9711
# Epoch 48/50
# 1500/1500 [==============================] - 1s 824us/step - loss: 0.0779 - accuracy: 0.9712 - val_loss: 0.5156 - val_accuracy: 0.8894
# Epoch 49/50
# 1500/1500 [==============================] - 1s 895us/step - loss: 0.0766 - accuracy: 0.9710 - val_loss: 0.5368 - val_accuracy: 0.8894
# Epoch 50/50
# 1500/1500 [==============================] - 1s 805us/step - loss: 0.0751 - accuracy: 0.9707 - val_loss: 0.5298 - val_accuracy: 0.8911
# Best epoch: 41

# %%
eval_result = model.evaluate(img_test, label_test)
print("[test loss, test accuracy]: ", eval_result)
# Out:
# 313/313 [==============================] - 0s 999us/step - loss: 0.5946 - accuracy: 0.8897
# [test loss, test accuracy]:  [0.5945956110954285, 0.8896999955177307]
