# %%
import tensorflow as tf
from tensorflow import keras

# %%
import keras_tuner as kt

# %%
(img_train, label_train), (img_test, label_test) = keras.datasets.fashion_mnist.load_data()

# %%
# Normalize pixel values between 0 and 1
img_train = img_train.astype('float32') / 255.0
img_test = img_test.astype('float32') / 255.0

# %%
def model_builder(hp):
  model = keras.Sequential()
  model.add(keras.layers.Flatten(input_shape=(28, 28)))

  # Tune the number of units in the first Dense layer
  # Choose an optimal value between 32-512
  hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
  model.add(keras.layers.Dense(units=hp_units, activation='relu'))
  model.add(keras.layers.Dense(10))

  # Tune the learning rate for the optimizer
  # Choose an optimal value from 0.01, 0.001, or 0.0001
  hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

  model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])

  return model

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_accuracy',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt')

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(img_train, label_train, epochs=50, validation_split=0.2, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# Trial 30 Complete [00h 00m 22s]
# val_accuracy: 0.8756666779518127
#
# Best val_accuracy So Far: 0.893833339214325
# Total elapsed time: 00h 04m 35s
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 256 and the optimal learning rate for the optimizer
# is 0.001.

# %%
# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
model = tuner.hypermodel.build(best_hps)
history = model.fit(img_train, label_train, epochs=50, validation_split=0.2)

val_acc_per_epoch = history.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Epoch 1/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.5056 - accuracy: 0.8211 - val_loss: 0.4385 - val_accuracy: 0.8430
# Epoch 2/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3779 - accuracy: 0.8629 - val_loss: 0.4013 - val_accuracy: 0.8568
# Epoch 3/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3375 - accuracy: 0.8761 - val_loss: 0.3403 - val_accuracy: 0.8791
# Epoch 4/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3117 - accuracy: 0.8854 - val_loss: 0.3324 - val_accuracy: 0.8810
# Epoch 5/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2918 - accuracy: 0.8929 - val_loss: 0.3310 - val_accuracy: 0.8822
# Epoch 6/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2769 - accuracy: 0.8965 - val_loss: 0.3262 - val_accuracy: 0.8825
# Epoch 7/50
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.2621 - accuracy: 0.9029 - val_loss: 0.3315 - val_accuracy: 0.8844
# Epoch 8/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2492 - accuracy: 0.9068 - val_loss: 0.3156 - val_accuracy: 0.8892
# Epoch 9/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2393 - accuracy: 0.9103 - val_loss: 0.3196 - val_accuracy: 0.8881
# Epoch 10/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2308 - accuracy: 0.9140 - val_loss: 0.3238 - val_accuracy: 0.8884
# Epoch 11/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2196 - accuracy: 0.9192 - val_loss: 0.3207 - val_accuracy: 0.8915
# Epoch 12/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2124 - accuracy: 0.9198 - val_loss: 0.3394 - val_accuracy: 0.8882
# Epoch 13/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2058 - accuracy: 0.9231 - val_loss: 0.3067 - val_accuracy: 0.8973
# Epoch 14/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1966 - accuracy: 0.9253 - val_loss: 0.3194 - val_accuracy: 0.8932
# Epoch 15/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1924 - accuracy: 0.9285 - val_loss: 0.3174 - val_accuracy: 0.8958
# Epoch 16/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1862 - accuracy: 0.9300 - val_loss: 0.3209 - val_accuracy: 0.8922
# Epoch 17/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1804 - accuracy: 0.9332 - val_loss: 0.3332 - val_accuracy: 0.8897
# Epoch 18/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1700 - accuracy: 0.9355 - val_loss: 0.3419 - val_accuracy: 0.8917
# Epoch 19/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1675 - accuracy: 0.9372 - val_loss: 0.3378 - val_accuracy: 0.8950
# Epoch 20/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1629 - accuracy: 0.9382 - val_loss: 0.3420 - val_accuracy: 0.8935
# Epoch 21/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1593 - accuracy: 0.9404 - val_loss: 0.3372 - val_accuracy: 0.8939
# Epoch 22/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1507 - accuracy: 0.9436 - val_loss: 0.3642 - val_accuracy: 0.8879
# Epoch 23/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1478 - accuracy: 0.9441 - val_loss: 0.3469 - val_accuracy: 0.8979
# Epoch 24/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1456 - accuracy: 0.9456 - val_loss: 0.3540 - val_accuracy: 0.8937
# Epoch 25/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1386 - accuracy: 0.9481 - val_loss: 0.3648 - val_accuracy: 0.8944
# Epoch 26/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1371 - accuracy: 0.9489 - val_loss: 0.3596 - val_accuracy: 0.8981
# Epoch 27/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1337 - accuracy: 0.9497 - val_loss: 0.3556 - val_accuracy: 0.8972
# Epoch 28/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1326 - accuracy: 0.9496 - val_loss: 0.3990 - val_accuracy: 0.8891
# Epoch 29/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1263 - accuracy: 0.9526 - val_loss: 0.3971 - val_accuracy: 0.8939
# Epoch 30/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1221 - accuracy: 0.9536 - val_loss: 0.3872 - val_accuracy: 0.8953
# Epoch 31/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1200 - accuracy: 0.9546 - val_loss: 0.3999 - val_accuracy: 0.8960
# Epoch 32/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1179 - accuracy: 0.9565 - val_loss: 0.4264 - val_accuracy: 0.8877
# Epoch 33/50
# 1500/1500 [==============================] - 1s 942us/step - loss: 0.1151 - accuracy: 0.9575 - val_loss: 0.4058 - val_accuracy: 0.8966
# Epoch 34/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1121 - accuracy: 0.9572 - val_loss: 0.3984 - val_accuracy: 0.8933
# Epoch 35/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1074 - accuracy: 0.9593 - val_loss: 0.4372 - val_accuracy: 0.8885
# Epoch 36/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1080 - accuracy: 0.9594 - val_loss: 0.4220 - val_accuracy: 0.8899
# Epoch 37/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1038 - accuracy: 0.9615 - val_loss: 0.4384 - val_accuracy: 0.8947
# Epoch 38/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1003 - accuracy: 0.9623 - val_loss: 0.4430 - val_accuracy: 0.8923
# Epoch 39/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1023 - accuracy: 0.9609 - val_loss: 0.4533 - val_accuracy: 0.8890
# Epoch 40/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0951 - accuracy: 0.9641 - val_loss: 0.4612 - val_accuracy: 0.8924
# Epoch 41/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0935 - accuracy: 0.9650 - val_loss: 0.4437 - val_accuracy: 0.8950
# Epoch 42/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0942 - accuracy: 0.9643 - val_loss: 0.4568 - val_accuracy: 0.8912
# Epoch 43/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0909 - accuracy: 0.9655 - val_loss: 0.4739 - val_accuracy: 0.8927
# Epoch 44/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0867 - accuracy: 0.9672 - val_loss: 0.4810 - val_accuracy: 0.8897
# Epoch 45/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0848 - accuracy: 0.9683 - val_loss: 0.5039 - val_accuracy: 0.8898
# Epoch 46/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0872 - accuracy: 0.9668 - val_loss: 0.4884 - val_accuracy: 0.8867
# Epoch 47/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0826 - accuracy: 0.9691 - val_loss: 0.5357 - val_accuracy: 0.8847
# Epoch 48/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0838 - accuracy: 0.9685 - val_loss: 0.4866 - val_accuracy: 0.8925
# Epoch 49/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0794 - accuracy: 0.9706 - val_loss: 0.5145 - val_accuracy: 0.8931
# Epoch 50/50
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0780 - accuracy: 0.9702 - val_loss: 0.5471 - val_accuracy: 0.8906
# Best epoch: 26

# %%
hypermodel = tuner.hypermodel.build(best_hps)

# Retrain the model
hypermodel.fit(img_train, label_train, epochs=best_epoch, validation_split=0.2)
# Out:
# Epoch 1/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.5001 - accuracy: 0.8238 - val_loss: 0.3858 - val_accuracy: 0.8616
# Epoch 2/26
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.3733 - accuracy: 0.8663 - val_loss: 0.3664 - val_accuracy: 0.8676
# Epoch 3/26
# 1500/1500 [==============================] - 2s 2ms/step - loss: 0.3350 - accuracy: 0.8767 - val_loss: 0.3552 - val_accuracy: 0.8749
# Epoch 4/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.3099 - accuracy: 0.8849 - val_loss: 0.3457 - val_accuracy: 0.8764
# Epoch 5/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2885 - accuracy: 0.8931 - val_loss: 0.3465 - val_accuracy: 0.8730
# Epoch 6/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2731 - accuracy: 0.8972 - val_loss: 0.3137 - val_accuracy: 0.8887
# Epoch 7/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2600 - accuracy: 0.9040 - val_loss: 0.3317 - val_accuracy: 0.8785
# Epoch 8/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2478 - accuracy: 0.9066 - val_loss: 0.3567 - val_accuracy: 0.8792
# Epoch 9/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2393 - accuracy: 0.9103 - val_loss: 0.3256 - val_accuracy: 0.8888
# Epoch 10/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2297 - accuracy: 0.9140 - val_loss: 0.3271 - val_accuracy: 0.8909
# Epoch 11/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2175 - accuracy: 0.9182 - val_loss: 0.3201 - val_accuracy: 0.8914
# Epoch 12/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2124 - accuracy: 0.9200 - val_loss: 0.3264 - val_accuracy: 0.8873
# Epoch 13/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.2038 - accuracy: 0.9238 - val_loss: 0.3299 - val_accuracy: 0.8878
# Epoch 14/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1960 - accuracy: 0.9250 - val_loss: 0.3227 - val_accuracy: 0.8898
# Epoch 15/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1904 - accuracy: 0.9278 - val_loss: 0.3190 - val_accuracy: 0.8953
# Epoch 16/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1829 - accuracy: 0.9310 - val_loss: 0.3327 - val_accuracy: 0.8909
# Epoch 17/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1760 - accuracy: 0.9341 - val_loss: 0.3319 - val_accuracy: 0.8897
# Epoch 18/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1704 - accuracy: 0.9357 - val_loss: 0.3345 - val_accuracy: 0.8912
# Epoch 19/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1706 - accuracy: 0.9361 - val_loss: 0.3368 - val_accuracy: 0.8925
# Epoch 20/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1614 - accuracy: 0.9391 - val_loss: 0.3494 - val_accuracy: 0.8910
# Epoch 21/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1555 - accuracy: 0.9413 - val_loss: 0.3303 - val_accuracy: 0.8938
# Epoch 22/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1531 - accuracy: 0.9418 - val_loss: 0.3495 - val_accuracy: 0.8930
# Epoch 23/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1473 - accuracy: 0.9430 - val_loss: 0.3727 - val_accuracy: 0.8870
# Epoch 24/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1448 - accuracy: 0.9456 - val_loss: 0.3999 - val_accuracy: 0.8830
# Epoch 25/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1378 - accuracy: 0.9473 - val_loss: 0.4219 - val_accuracy: 0.8858
# Epoch 26/26
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1357 - accuracy: 0.9488 - val_loss: 0.3716 - val_accuracy: 0.8937

# %%
eval_result = hypermodel.evaluate(img_test, label_test)
print("[test loss, test accuracy]:", eval_result)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.4097 - accuracy: 0.8875
# [test loss, test accuracy]: [0.409717321395874, 0.887499988079071]
